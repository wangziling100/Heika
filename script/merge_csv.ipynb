# %%
from merge_csv import main

# %%
conf_files =['tag 1']
df, miss = main(conf_files)
# Out:
# /home/jovyan/Heika/script/../data/log/merge_csv.log
# 0.02267657992565056
# 0.016743854649091557
# 0.018599562363238512

# %%
df.to_csv('../data/all_data.csv')

# %%
df.shape
# Out:
# (11046, 32)

# %%
miss
# Out:
# ['../data/1te_Woche/1_tag/heika002_d1_e1_1_p2.csv',
#  '../data/1te_Woche/1_tag/heika002_d1_e1_2_p1.csv',
#  '../data/1te_Woche/1_tag/heika002_d1_e1_2_p2.csv',
#  '../data/1te_Woche/1_tag/heika002_d1_e2_1.csv',
#  '../data/1te_Woche/1_tag/heika002_d1_e3_3.csv',
#  '../data/1te_Woche/1_tag/heika002_d1_e2_2.csv',
#  '../data/1te_Woche/1_tag/heika002_d1_e4_1.csv',
#  '../data/1te_Woche/1_tag/heika002_d1_e4_2.csv',
#  '../data/1te_Woche/1_tag/heika002_d1_e4_3.csv',
#  '../data/1te_Woche/1_tag/heika002_d1_e5_1.csv',
#  '../data/1te_Woche/1_tag/heika002_d1_e5_2.csv',
#  '../data/1te_Woche/1_tag/heika002_d1_e5_3.csv',
#  '../data/1te_Woche/1_tag/heika002_d1_e6_1.csv',
#  '../data/1te_Woche/1_tag/heika002_d1_e6_2.csv',
#  '../data/1te_Woche/1_tag/heika002_d1_e6_3.csv',
#  '../data/1te_Woche/1_tag/heika002_d1_e6_4.csv',
#  '../data/1te_Woche/1_tag/heika002_d1_e7_1.csv',
#  '../data/1te_Woche/1_tag/heika002_d1_e7_2.csv',
#  '../data/1te_Woche/1_tag/heika002_d1_e7_3.csv',
# ...
