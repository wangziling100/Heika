# %%
from merge_csv import main

# %%
df = main()
# Out:
# /home/jovyan/Heika/script/../data/log/merge_csv.log
# 0.02267657992565056
# 0.016743854649091557
# 0.018599562363238512

# %%
df
# Out:
#       Force Input         Fx         Fy         Fz         Mx         My  \
# 0             NaN   0.000000   0.000000   0.000000   0.000000   0.000000
# 1             NaN   0.000000   0.000000   0.000000   0.000000   0.000000
# 2             NaN   0.000000   0.000000   0.000000   0.000000   0.000000
# 3             NaN   0.000000   0.000000   0.000000   0.000000   0.000000
# 4             NaN   0.000000   0.000000   0.000000   0.000000   0.000000
# 5             NaN   0.000000   0.000000   0.000000   0.000000   0.000000
# 6             NaN   0.000000   0.000000   0.000000   0.000000   0.000000
# 7             NaN   0.000000   0.000000   0.000000   0.000000   0.000000
# 8             NaN   0.000000   0.000000   0.000000   0.000000   0.000000
# 9             NaN   0.000000   0.000000   0.000000   0.000000   0.000000
# 10            NaN   0.000000   0.000000   0.000000   0.000000   0.000000
# 11            NaN   0.000000   0.000000   0.000000   0.000000   0.000000
# ...
